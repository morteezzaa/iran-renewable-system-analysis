# %% [markdown]
# # Creating the model with CO2 limit

# %% [markdown]
# in this notebook, the model created in model.ipynb will be imported and global_constraints of CO2 limit will be applied.

# %% [markdown]
# ## Importing packages

# %%
import linopy
import pypsa

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

import cartopy
import cartopy.crs as ccrs

import networkx as nx

import atlite
from atlite.gis import ExclusionContainer, shape_availability
from rasterio.plot import show
from rasterio.crs import CRS
import rasterio as rio

from pathlib import Path
import xarray as xr

# %% [markdown]
# ## Importing the base model

# %%
n_no_co2 = pypsa.Network("pypsa_model_n.nc") # the model without CO2 limits is imported
# Out:
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 1.0.5)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, links, loads, storage_units, sub_networks

# %%
n_no_co2.global_constraints
# Out:
# Empty DataFrame
# Columns: [type, investment_period, bus, carrier_attribute, sense, constant, mu]
# Index: []

# %% [markdown]
# ## Adding co2 limit constraint

# %%
n_no_co2.add(
    "GlobalConstraint",
    "CO2Limit",
    carrier_attribute="co2_emissions",
    sense="<=",
    constant=0, # the CO2 limit is 0 --> 100% renewable system
)

# %%
n_no_co2.global_constraints
# Out:
#                     type  investment_period bus carrier_attribute sense  \
# name
# CO2Limit  primary_energy                NaN         co2_emissions    <=
#
#           constant   mu
# name
# CO2Limit       0.0  0.0

# %% [markdown]
# ## Solving the model

# %%
# solve the model with co2 limit
n_no_co2.optimize(
    snapshots=n_no_co2.snapshots[:168],  # 1 week
    solver_name="gurobi",
    log_to_console=False
)
# Out:
# INFO:linopy.model: Solve problem using Gurobi solver
# INFO:linopy.model:Solver options:
#  - log_to_console: False
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 19/19 [00:00<00:00, 64.63it/s]
# Writing continuous variables.: 100%|██████████| 8/8 [00:00<00:00, 481.96it/s]
# INFO:linopy.io: Writing time: 0.32s
# Set parameter Username
# INFO:gurobipy:Set parameter Username
# Set parameter LicenseID to value 2750042
# INFO:gurobipy:Set parameter LicenseID to value 2750042
# Academic license - for non-commercial use only - expires 2026-12-04
# INFO:gurobipy:Academic license - for non-commercial use only - expires 2026-12-04
# Read LP format model from file /private/var/folders/h3/z_4l05b96rn0jmfgxq7ty0lw0000gn/T/linopy-problem-3yosgli6.lp
# INFO:gurobipy:Read LP format model from file /private/var/folders/h3/z_4l05b96rn0jmfgxq7ty0lw0000gn/T/linopy-problem-3yosgli6.lp
# Reading time = 0.24 seconds
# INFO:gurobipy:Reading time = 0.24 seconds
# obj: 289191 rows, 126497 columns, 619001 nonzeros
# INFO:gurobipy:obj: 289191 rows, 126497 columns, 619001 nonzeros
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.2.0 25C56)
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Apple M4 Pro
# INFO:gurobipy:Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:LogToConsole  0
# INFO:gurobipy:
# INFO:gurobipy:Optimize a model with 289191 rows, 126497 columns and 619001 nonzeros (Min)
# INFO:gurobipy:Model fingerprint: 0xcae01f90
# INFO:gurobipy:Model has 18641 linear objective coefficients
# INFO:gurobipy:Coefficient statistics:
# INFO:gurobipy:  Matrix range     [7e-09, 7e+02]
# INFO:gurobipy:  Objective range  [1e-02, 2e+05]
# INFO:gurobipy:  Bounds range     [0e+00, 0e+00]
# INFO:gurobipy:  RHS range        [2e+00, 4e+05]
# INFO:gurobipy:Presolve removed 137796 rows and 9381 columns
# INFO:gurobipy:Presolve time: 0.19s
# INFO:gurobipy:Presolved: 151395 rows, 117116 columns, 477705 nonzeros
# INFO:gurobipy:
# INFO:gurobipy:Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# INFO:gurobipy:Showing barrier log only...
# INFO:gurobipy:
# INFO:gurobipy:Ordering time: 0.53s
# INFO:gurobipy:
# INFO:gurobipy:Barrier statistics:
# INFO:gurobipy: Dense cols : 298
# INFO:gurobipy: AA' NZ     : 5.413e+05
# INFO:gurobipy: Factor NZ  : 5.906e+06 (roughly 160 MB of memory)
# INFO:gurobipy: Factor Ops : 3.882e+09 (less than 1 second per iteration)
# INFO:gurobipy: Threads    :
# INFO:gurobipy:  76   2.84977747e+10  2.84977553e+10  6.08e-07 5.59e-09  7.97e-02     4s
# INFO:gurobipy:  77   2.84977658e+10  2.84977562e+10  3.98e-07 9.31e-09  3.93e-02     4s
# INFO:gurobipy:  78   2.84977632e+10  2.84977564e+10  2.78e-07 7.45e-09  2.79e-02     5s
# INFO:gurobipy:  79   2.84977616e+10  2.84977564e+10  8.68e-07 1.12e-08  2.14e-02     5s
# INFO:gurobipy:  80   2.84977592e+10  2.84977565e+10  3.64e-06 4.47e-08  1.09e-02     5s
# INFO:gurobipy:  81   2.84977578e+10  2.84977566e+10  1.00e-05 4.47e-08  5.31e-03     5s
# INFO:gurobipy:  82   2.84977576e+10  2.84977566e+10  4.30e-04 9.31e-09  4.16e-03     5s
# INFO:gurobipy:  83   2.84977574e+10  2.84977566e+10  3.27e-04 7.45e-09  3.11e-03     5s
# INFO:gurobipy:  84   2.84977571e+10  2.84977566e+10  2.02e-04 1.12e-08  1.99e-03     5s
# INFO:gurobipy:  85   2.84977569e+10  2.84977567e+10  1.22e-04 2.98e-08  1.19e-03     5s
# INFO:gurobipy:  86   2.84977567e+10  2.84977567e+10  4.54e-05 7.45e-09  1.24e-04     5s
# INFO:gurobipy:  87   2.84977567e+10  2.84977567e+10  5.17e-06 9.31e-09  1.74e-06     5s
# INFO:gurobipy:  88   2.84977567e+10  2.84977567e+10  6.26e-08 2.98e-08  7.05e-10     5s
# INFO:gurobipy:
# INFO:gurobipy:Barrier solved model in 88 iterations and 5.10 seconds (12.40 work units)
# INFO:gurobipy:Optimal objective 2.84977567e+10
# INFO:gurobipy:
# INFO:gurobipy:Crossover log...
# INFO:gurobipy:
# INFO:gurobipy:   88285 DPushes remaining with DInf 0.0000000e+00                 5s
# INFO:gurobipy:       0 DPushes remaining with DInf 0.0000000e+00                 6s
# INFO:gurobipy:
# INFO:gurobipy:   12612 PPushes remaining with PInf 0.0000000e+00                 6s
# INFO:gurobipy:       0 PPushes remaining with PInf 0.0000000e+00                 6s
# INFO:gurobipy:
# INFO:gurobipy:  Push phase complete: Pinf 0.0000000e+00, Dinf 8.0560961e-09      6s
# INFO:gurobipy:
# INFO:gurobipy:Crossover time: 1.06 seconds (3.12 work units)
# INFO:gurobipy:
# INFO:gurobipy:Solved with barrier
# INFO:gurobipy:Iteration    Objective       Primal Inf.    Dual Inf.      Time
# INFO:gurobipy:   49575    2.8497757e+10   0.000000e+00   0.000000e+00      6s
# INFO:gurobipy:
# INFO:gurobipy:Solved in 49575 iterations and 6.22 seconds (15.62 work units)
# INFO:gurobipy:Optimal objective  2.849775667e+10
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 126497 primals, 289191 duals
# Objective: 2.85e+10
# Solver model: available
# Solver message: 2
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-fix-p-lower, Generator-fix-p-upper, Generator-ext-p-lower, Generator-ext-p-upper, Link-ext-p-lower, Link-ext-p-upper, StorageUnit-ext-p_dispatch-lower, StorageUnit-ext-p_dispatch-upper, StorageUnit-ext-p_store-lower, StorageUnit-ext-p_store-upper, StorageUnit-ext-state_of_charge-lower, StorageUnit-ext-state_of_charge-upper, StorageUnit-energy_balance were not assigned to the network.
# ('ok', 'optimal')

# %%
n_no_co2.objective / 1e6 # in Mio. €
# Out:
# 28497.756665749355

# %% [markdown]
# ## Exporting the model into a .nc file

# %%
n_no_co2.export_to_netcdf("pypsa_model_n_no_co2.nc")
